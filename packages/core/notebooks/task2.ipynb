# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../data/filtered_reviews.csv')

display(df.head())

display(df.dtypes)
# Out:
#              game  author_num_games_owned  author_num_reviews  \
# 0  Counter-Strike                    41.0                10.0
# 1  Counter-Strike                     0.0                 1.0
# 2  Counter-Strike                    50.0                50.0
# 3  Counter-Strike                    11.0                 5.0
# 4  Counter-Strike                     0.0                27.0
#
#    author_playtime_at_review language  \
# 0                      221.0  english
# 1                   396410.0  english
# 2                       81.0  english
# 3                       78.0  english
# 4                    26568.0  english
#
#                                               review  voted_up  votes_funny  \
# 0                                         cs 1.6>cs2         1         13.0
# 1                #1 PLAYED PC GAME ONLINE SINCE 1999         1          1.0
# 2  best played with a membrane keyboard, a roller...         1         31.0
# 3  My friend who I play counter-strike with said ...         1         19.0
# 4  Counter-Strike won't ever be canceled. Counter...         1          2.0
#
#    weighted_vote_score  steam_purchase  received_for_free  \
# 0             0.863652               1                  0
# 1             0.865922               1                  0
# 2             0.935513               1                  0
# 3             0.875650               1                  0
# 4             0.877432               1                  0
#
#    written_during_early_access
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# game                            object
# author_num_games_owned         float64
# author_num_reviews             float64
# author_playtime_at_review      float64
# language                        object
# review                          object
# voted_up                         int64
# votes_funny                    float64
# weighted_vote_score            float64
# steam_purchase                   int64
# received_for_free                int64
# written_during_early_access      int64
# dtype: object

# %%
# Removing duplicates and NaNs
duplicate_count = df.duplicated().sum()
print(f"Found {duplicate_count} duplicate rows.")

if duplicate_count > 0:
    df.drop_duplicates(inplace=True)
    print("Duplicates removed.")

duplicate_count = df.duplicated().sum()
print(f"\nFound {duplicate_count} duplicate rows.")


print("\nMissing values per column:")
print(df.isnull().sum())


df.dropna(inplace=True)

print("Rows with NaN values removed.")

print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Found 119 duplicate rows.
# Duplicates removed.
#
# Found 0 duplicate rows.
#
# Missing values per column:
# game                           12
# author_num_games_owned          0
# author_num_reviews              0
# author_playtime_at_review       0
# language                        0
# review                          8
# voted_up                        0
# votes_funny                     0
# weighted_vote_score             0
# steam_purchase                  0
# received_for_free               0
# written_during_early_access     0
# dtype: int64
# Rows with NaN values removed.
#
# Missing values per column:
# game                           0
# author_num_games_owned         0
# author_num_reviews             0
# author_playtime_at_review      0
# language                       0
# review                         0
# voted_up                       0
# votes_funny                    0
# weighted_vote_score            0
# steam_purchase                 0
# received_for_free              0
# written_during_early_access    0
# dtype: int64

# %%
# Dropping columbns because they dont really matter
df.drop(columns=['game', 'language'], inplace=True)

print(f"\nDropped unnecessary columns") 
display(df.dtypes)
# Out:
# Dropped unnecessary columns
# author_num_games_owned         float64
# author_num_reviews             float64
# author_playtime_at_review      float64
# review                          object
# voted_up                         int64
# votes_funny                    float64
# weighted_vote_score            float64
# steam_purchase                   int64
# received_for_free                int64
# written_during_early_access      int64
# dtype: object

# %%
# Normalizing numeric columns 

# Identify numeric columns to scale
numeric_cols = [
    'author_num_games_owned', 
    'author_num_reviews', 
    'author_playtime_at_review', 
    'votes_funny', 
    'weighted_vote_score'
]


for col in numeric_cols:   
    if col in ['author_playtime_at_review', 'votes_funny', 'author_num_games_owned', 'author_num_reviews']:
        df[col] = np.log1p(df[col])


# Now, initialize and apply the StandardScaler as before
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

print("Numeric features log-transformed and scaled.")

print(df[numeric_cols].describe())

display(df.head())
# Out:
# Numeric features log-transformed and scaled.
#        author_num_games_owned  author_num_reviews  author_playtime_at_review  \
# count            1.930350e+05        1.930350e+05               1.930350e+05
# mean            -8.009641e-17        3.262751e-16               1.319235e-16
# std              1.000003e+00        1.000003e+00               1.000003e+00
# min             -1.020995e+00       -1.590167e+00              -2.217488e+00
# 25%             -1.020995e+00       -7.764781e-01              -5.136467e-01
# 50%              2.705615e-01       -9.782557e-02               8.780575e-02
# 75%              9.045212e-01        6.469161e-01               6.259403e-01
# max              2.404858e+00        4.748153e+00               3.265479e+00
#
#         votes_funny  weighted_vote_score
# count  1.930350e+05         1.930350e+05
# mean  -2.709143e-17         1.225004e-15
# std    1.000003e+00         1.000003e+00
# min   -1.543637e+00        -1.388832e+00
# 25%   -7.410606e-01        -8.375061e-01
# 50%   -1.050342e-01        -1.842300e-01
# 75%    7.211752e-01         6.877724e-01
# max    1.129758e+01         3.255236e+00
#    author_num_games_owned  author_num_reviews  author_playtime_at_review  \
# 0                0.219404           -0.327542                  -0.291339
# 1               -1.020995           -1.590167                   2.378096
# 2                0.283838            0.808566                  -0.646415
# 3               -0.196343           -0.776478                  -0.659703
# 4               -1.020995            0.364456                   1.414534
#
#                                               review  voted_up  votes_funny  \
# 0                                         cs 1.6>cs2         1    -0.015791
# 1                #1 PLAYED PC GAME ONLINE SINCE 1999         1    -1.142349
# 2  best played with a membrane keyboard, a roller...         1     0.462803
# 3  My friend who I play counter-strike with said ...         1     0.190701
# 4  Counter-Strike won't ever be canceled. Counter...         1    -0.907610
#
#    weighted_vote_score  steam_purchase  received_for_free  \
# 0             0.122850               1                  0
# 1             0.176756               1                  0
# 2             1.829478               1                  0
# 3             0.407797               1                  0
# 4             0.450100               1                  0
#
#    written_during_early_access
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
df.to_csv('../data/cleaned_reviews.csv', index=False)

print("Cleaned data saved to '../data/cleaned_reviews.csv'")
display(df.info)
display(df.dtypes)
# Out:
# Cleaned data saved to '../data/cleaned_reviews.csv'
# <bound method DataFrame.info of         author_num_games_owned  author_num_reviews  author_playtime_at_review  \
# 0                     0.219404           -0.327542                  -0.291339
# 1                    -1.020995           -1.590167                   2.378096
# 2                     0.283838            0.808566                  -0.646415
# 3                    -0.196343           -0.776478                  -0.659703
# 4                    -1.020995            0.364456                   1.414534
# ...                        ...                 ...                        ...
# 193169                0.972299            1.212600                  -0.278718
# 193170                0.978775            0.988220                  -1.115477
# 193171               -1.020995           -0.050025                  -0.561681
# 193172                0.493749           -0.476170                  -1.476130
# 193173                1.650217            2.045672                  -0.993211
#
#                                                    review  voted_up  \
# 0                                              cs 1.6>cs2         1
# 1                     #1 PLAYED PC GAME ONLINE SINCE 1999         1
# 2       best played with a membrane keyboard, a roller...         1
# 3       My friend who I play counter-strike with said ...         1
# 4       Counter-Strike won't ever be canceled. Counter...         1
# ...                                                   ...       ...
# 193169  After putting some more time into this game, y...         1
# 193170  >goes inside the store >shoots hostage >refuse...         1
# 193171  Even if this game starts out as a walking simu...         1
# 193172  Hey, good job :)  I quite liked the game, I wa...         1
# 193173  Let's start off with, I would not have purchas...         0
#
#         votes_funny  weighted_vote_score  steam_purchase  received_for_free  \
# 0         -0.015791             0.122850               1                  0
# 1         -1.142349             0.176756               1                  0
# 2          0.462803             1.829478               1                  0
# 3          0.190701             0.407797               1                  0
# 4         -0.907610             0.450100               1                  0
# ...             ...                  ...             ...                ...
# 193169    -0.506322            -0.509941               1                  0
# 193170     2.109404             0.653747               1                  0
# 193171    -0.015791            -0.015106               1                  0
# 193172    -0.339773            -0.463316               0                  0
# 193173    -1.142349            -1.149324               0                  1
#
#         written_during_early_access
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 193169                            1
# 193170                            1
# 193171                            1
# 193172                            0
# 193173                            0
#
# [193035 rows x 10 columns]>
# author_num_games_owned         float64
# author_num_reviews             float64
# author_playtime_at_review      float64
# review                          object
# voted_up                         int64
# votes_funny                    float64
# weighted_vote_score            float64
# steam_purchase                   int64
# received_for_free                int64
# written_during_early_access      int64
# dtype: object
